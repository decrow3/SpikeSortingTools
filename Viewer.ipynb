# %%
import spikeinterface as si
import spikeinterface.extractors as se
import spikeinterface.widgets as sw
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
# List of file paths to load
# file0=   "/mnt/NPX/Rocky/20240826/Ephys/20240826V2V1PSC/catgt_Rocky20240826_V2MT_g0/Rocky20240826_V2MT_g0_imec1/Rocky20240826_V2MT_g0_tcat.imec1.ap.bin"
file0 = "/mnt/NPX/Luke/20251204/Luke12042025_V1_RH_g0/Luke12042025_V1_RH_g0_imec1/Luke12042025_V1_RH_g0_t0.imec1.ap.bin"

#file0= "/home/huklab/Documents/RyanSorting/SpikeSortingTools/pipeline_results_test0/preprocessed_recording"
# Load recording0, which is a .bin file from catGT
recording0 = se.read_binary(file0, sampling_frequency=30000, num_chan=385, dtype='int16')
#recording1 = si.core.load_extractor(file1)#, sampling_frequency=30000, num_chan=384, dtype='int16')
# Out:
# /home/huklab/anaconda3/envs/spikeinterface/lib/python3.12/site-packages/spikeinterface/core/binaryrecordingextractor.py:76: UserWarning: `num_chan` is to be deprecated as of version 0.100, please use `num_channels` instead
#   warnings.warn("`num_chan` is to be deprecated as of version 0.100, please use `num_channels` instead")

# %%
#global car 

file1= "///mnt/NPX/Luke/20251204/pipeline_results_Luke12042025_V1_RH_g0_imec0/preprocessed_recording/"
# Load recording 1
recording1 = si.core.load_extractor(file1)#, sampling_frequency=30000, num_chan=384, dtype='int16')
# Out:
# /tmp/ipykernel_8727/4110609273.py:5: DeprecationWarning: load_extractor() is deprecated and will be removed in the future. Please use load() instead.
#   recording1 = si.core.load_extractor(file1)#, sampling_frequency=30000, num_chan=384, dtype='int16')

# %%
# Comparison with older recording
file2 = "/mnt/NPX/Luke/20251120/Luke1120_V1_RH_g0/Luke1120_V1_RH_g0_imec0/Luke1120_V1_RH_g0_t0.imec0.ap.bin"

#file0= "/home/huklab/Documents/RyanSorting/SpikeSortingTools/pipeline_results_test0/preprocessed_recording"
# Load recording0, which is a .bin file from catGT
recording2= se.read_binary(file2, sampling_frequency=30000, num_chan=385, dtype='int16')
#recording1 = si.core.load_extractor(file1)#, sampling_frequency=30000, num_chan=384, dtype='int16')
# Out:
# /home/huklab/anaconda3/envs/spikeinterface/lib/python3.12/site-packages/spikeinterface/core/binaryrecordingextractor.py:76: UserWarning: `num_chan` is to be deprecated as of version 0.100, please use `num_channels` instead
#   warnings.warn("`num_chan` is to be deprecated as of version 0.100, please use `num_channels` instead")

# %%
#global car 
file3 = "///mnt/NPX/Luke/20251120/pipeline_results_Luke1120_V1_RH_g0_imec0/preprocessed_recording/"
# Load recording 2, which is a traces segment from the preprocessed recording
recording3 = si.core.load_extractor(file3)#, sampling_frequency=30000, num_chan=384, dtype='int16')
# Out:
# /tmp/ipykernel_8727/2617787341.py:4: DeprecationWarning: load_extractor() is deprecated and will be removed in the future. Please use load() instead.
#   recording3 = si.core.load_extractor(file3)#, sampling_frequency=30000, num_chan=384, dtype='int16')

# %%
file3= ('/home/huklab/Documents/RyanSorting/SpikeSortingTools/pipeline_results_Rocky20240826_V1V2_g0_imec1_locar_100s_40_75/preprocessed_recording_premotion/')
# Load recording 3, which is a traces segment from the preprocessed recording
recording3 = si.core.load_extractor(file3)#, sampling_frequency=30000, num_chan=384, dtype='int16')

# %%
file4= "/home/huklab/Documents/RyanSorting/SpikeSortingTools/pipeline_results_Rocky20240826_V1V2_g0_imec1_10s/preprocessed_recording_premotion/"
# Load recording 4
recording4 = si.core.load_extractor(file4)#, sampling_frequency=30000, num_chan=384, dtype='int16')

# %%
file5= "/home/huklab/Documents/RyanSorting/SpikeSortingTools/pipeline_results_Luke01012026_V1_RH_g0_imec0/preprocessed_recording/"
# Load recording 3, which is a traces segment from the preprocessed recording
recording5 = si.core.load_extractor(file5)#, sampling_frequency=30000, num_chan=384, dtype='int16')
# Out:
# /tmp/ipykernel_1700104/3846238193.py:3: DeprecationWarning: load_extractor() is deprecated and will be removed in the future. Please use load() instead.
#   recording5 = si.core.load_extractor(file5)#, sampling_frequency=30000, num_chan=384, dtype='int16')

# %%
file7= "/home/huklab/Documents/RyanSorting/SpikeSortingTools/pipeline_results_Rocky20240826_V1V2_g0_imec1_100s_2/preprocessed_recording_premotion/"
# Load recording 3, which is a traces segment from the preprocessed recording
recording7 = si.core.load_extractor(file7)#, sampling_frequency=30000, num_chan=384, dtype='int16')

# %%
file8= "/home/huklab/Documents/RyanSorting/SpikeSortingTools/pipeline_results_Rocky20240826_V1V2_g0_imec1_100s_3/preprocessed_recording_premotion/"
# Load recording 3, which is a traces segment from the preprocessed recording
recording8 = si.core.load_extractor(file8)#, sampling_frequency=30000, num_chan=384, dtype='int16')

# %%
file9= "/home/huklab/Documents/RyanSorting/SpikeSortingTools/pipeline_results_Rocky20240826_V1V2_g0_imec1_100s_4/preprocessed_recording_premotion/"
# Load recording 3, which is a traces segment from the preprocessed recording
recording9 = si.core.load_extractor(file9)#, sampling_frequency=30000, num_chan=384, dtype='int16')

# %%
file10= "/home/huklab/Documents/RyanSorting/SpikeSortingTools/pipeline_results_Rocky20240826_V1V2_g0_imec1_100s_5/preprocessed_recording_premotion/"
# Load recording 3, which is a traces segment from the preprocessed recording
recording10 = si.core.load_extractor(file10)#, sampling_frequency=30000, num_chan=384, dtype='int16')

# %%
# Plot recordings for comparison, raw file first
sw.plot_traces(recording0,backend='ipywidgets')
# Out:
# AppLayout(children=(TimeSlider(children=(Dropdown(description='segment', options=(0,), value=0), Button(icon='…

# %%
# Plot recordings for comparison, CATGT on top
sw.plot_traces(recording1,backend='ipywidgets')
# Out:
# AppLayout(children=(TimeSlider(children=(Dropdown(description='segment', options=(0,), value=0), Button(icon='…

# %%
sw.plot_traces(recording2,backend='ipywidgets')
# Out:
# AppLayout(children=(TimeSlider(children=(Dropdown(description='segment', options=(0,), value=0), Button(icon='…

# %%
sw.plot_traces(recording3,backend='ipywidgets')
# Out:
# AppLayout(children=(TimeSlider(children=(Dropdown(description='segment', options=(0,), value=0), Button(icon='…

# %%
sw.plot_traces(recording4,backend='ipywidgets')

# %%
sw.plot_traces(recording5,backend='ipywidgets')
# Out:
# AppLayout(children=(TimeSlider(children=(Dropdown(description='segment', options=(0,), value=0), Button(icon='…

# %%
sw.plot_traces(recording7,backend='ipywidgets')

# %%
sw.plot_traces(recording9,backend='ipywidgets')

# %%
sw.plot_traces(recording10,backend='ipywidgets')

# %%
sw.plot_traces(recording8,backend='ipywidgets')
