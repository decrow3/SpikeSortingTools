# %%
import spikeinterface as si
import spikeinterface.extractors as se
import spikeinterface.widgets as sw
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
# List of file paths to load
file1=   "/home/huklab/Documents/SpikeSorting/Working/Rocky/20240707_2/catgt_Rocky20240707_V1V2_g0/Rocky20240707_V1V2_g0_imec0/Rocky20240707_V1V2_g0_tcat.imec0.ap.bin"
#file1= "/home/huklab/Documents/RyanSorting/SpikeSortingTools/pipeline_results_test0/preprocessed_recording"
# Load recording 1, which is a .bin file from catGT
recording1 = se.read_binary(file1, sampling_frequency=30000, num_chan=385, dtype='int16')
#recording1 = si.core.load_extractor(file1)#, sampling_frequency=30000, num_chan=384, dtype='int16')

# %%
#global car 
file2= "/home/huklab/Documents/RyanSorting/SpikeSortingTools/pipeline_results_Rocky20240704_V1V2_g0_imec0_785s_slice/preprocessed_recording"
# Load recording 2, which is a traces segment from the preprocessed recording
recording2 = si.core.load_extractor(file2)#, sampling_frequency=30000, num_chan=384, dtype='int16')
# Out:
# /tmp/ipykernel_3196797/1537834116.py:4: DeprecationWarning: load_extractor() is deprecated and will be removed in the future. Please use load() instead.
#   recording2 = si.core.load_extractor(file2)#, sampling_frequency=30000, num_chan=384, dtype='int16')

# %%
file3= "/home/huklab/Documents/RyanSorting/SpikeSortingTools/pipeline_results_Rocky20240704_V1V2_g0_imec0_locarfirst/preprocessed_recording"
# Load recording 3, which is a traces segment from the preprocessed recording
recording3 = si.core.load_extractor(file3)#, sampling_frequency=30000, num_chan=384, dtype='int16')
# Out:
# /tmp/ipykernel_4160502/3245645353.py:3: DeprecationWarning: load_extractor() is deprecated and will be removed in the future. Please use load() instead.
#   recording3 = si.core.load_extractor(file3)#, sampling_frequency=30000, num_chan=384, dtype='int16')

# %%
file4= ('/home/huklab/Documents/RyanSorting/SpikeSortingTools/pipeline_results_Rocky20240704_V1V2_g0_imec0_785s_sat_slice_th_10_8_nocur_pt8ccg/preprocessed_recording/')
# Load recording 4, which is a traces segment from the preprocessed recording
recording4 = si.core.load_extractor(file4)#, sampling_frequency=30000, num_chan=384, dtype='int16')
# Out:
# /tmp/ipykernel_3723467/3029535758.py:3: DeprecationWarning: load_extractor() is deprecated and will be removed in the future. Please use load() instead.
#   recording4 = si.core.load_extractor(file4)#, sampling_frequency=30000, num_chan=384, dtype='int16')

# %%
file5 = ('/home/huklab/Documents/RyanSorting/SpikeSortingTools/pipeline_results_Rocky20240704_V1V2_g0_imec0_locarfirst/preprocessed_recording_premotion/')
# Load recording 5, which is a traces segment from the preprocessed recording
recording5 = si.core.load_extractor(file5)#, sampling_frequency=30000, num_chan=384, dtype='int16')
# Out:
# /tmp/ipykernel_3723467/2417312238.py:3: DeprecationWarning: load_extractor() is deprecated and will be removed in the future. Please use load() instead.
#   recording5 = si.core.load_extractor(file5)#, sampling_frequency=30000, num_chan=384, dtype='int16')

# %%
# Plot recordings for comparison, CATGT on top
sw.plot_traces(recording1,backend='ipywidgets')

# %%
recording2

# %%
sw.plot_traces(recording2,backend='ipywidgets')
# Out:
# AppLayout(children=(TimeSlider(children=(Dropdown(description='segment', options=(0,), value=0), Button(icon='…

# %%
sw.plot_traces(recording3,backend='ipywidgets')
# Out:
# AppLayout(children=(TimeSlider(children=(Dropdown(description='segment', options=(0,), value=0), Button(icon='…

# %%
sw.plot_traces(recording4,backend='ipywidgets')
# Out:
# AppLayout(children=(TimeSlider(children=(Dropdown(description='segment', options=(0,), value=0), Button(icon='…

# %%
sw.plot_traces(recording5,backend='ipywidgets')
# Out:
# AppLayout(children=(TimeSlider(children=(Dropdown(description='segment', options=(0,), value=0), Button(icon='…
